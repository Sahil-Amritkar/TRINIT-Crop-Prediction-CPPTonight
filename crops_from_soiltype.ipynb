# %% [markdown]
# Crops from Soiltype

# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import PIL
import os
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import plot_confusion_matrix, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import pickle
from mpl_toolkits.axes_grid1 import ImageGrid
import math

# %%
image_size = 200
batch_size = 10
no_of_classes=8
class_labels=['Arid Soil', 'Black Soil','Cinder Soil', 'Laterite Soil','Peat Soil', 'Red Soil', 'Saline Soil', 'Yellow Soil']

target_size = (image_size, image_size)
input_shape = (image_size, image_size, 3)

# %%
test_datagen = ImageDataGenerator(rescale=1/255)

test_generator = test_datagen.flow_from_directory('CNN Model/test_images', 
        target_size=(image_size, image_size),
        batch_size = batch_size,
        classes = ['test'],
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 1 images belonging to 1 classes.

# %%
print (test_generator.class_indices)
print (test_generator.shuffle)
print (test_generator.samples)
# Out:
# {'test': 0}
# False
# 1

# %%
class_mapping = {v:k for k,v in test_generator.class_indices.items()}

# %%
x,y = next(test_generator)
print('x: ',type(x))
print('y: ',type(y))
print('x: ',x.shape)
print('y: ',y.shape)
# Out:
# x:  <class 'numpy.ndarray'>
# y:  <class 'numpy.ndarray'>
# x:  (1, 200, 200, 3)
# y:  (1, 1)

# %%
#Get class int vale from one hot encoded labels
y_int = np.argmax(y,axis=-1)
y_int
# Out:
# array([0])

# %%
def show_grid(image_list,nrows,ncols,label_list=None,show_labels=False,savename=None,figsize=(10,10),showaxis='off'):
    if type(image_list) is not list:
        if(image_list.shape[-1]==1):
            image_list = [image_list[i,:,:,0] for i in range(image_list.shape[0])]
        elif(image_list.shape[-1]==3):
            image_list = [image_list[i,:,:,:] for i in range(image_list.shape[0])]
    fig = plt.figure(None, figsize,frameon=False)
    grid = ImageGrid(fig, 111,  # similar to subplot(111)
                     nrows_ncols=(nrows, ncols),  # creates 2x2 grid of axes
                     axes_pad=0.3,  # pad between axes in inch.
                     share_all=True,
                     )
    for i in range(nrows*ncols):
        ax = grid[i]
        ax.imshow(image_list[i],cmap='Greys_r')  # The AxesGrid object work as a list of axes.
        ax.axis('off')
        if show_labels:
            ax.set_title(class_mapping[y_int[i]])
    if savename != None:
        plt.savefig(savename,bbox_inches='tight')

# %%
def n_maximum_elements(list1, N):
    final_list = []
 
    for i in range(0, N):
        max1 = 0
        max_pos=0
         
        for j in range(len(list1)):    
            if list1[j] > 0.1:
                max1 = list1[j];
                max_pos=j
                 
        list1.remove(max1);
        final_list.append(max_pos)
         
    return final_list

# %%
model = pickle.load(open('CNN Model/CNN_model.pickle', 'rb'))

# %%
y_prob = model.predict(test_generator)
y_prob
# Out:
# 2023-02-11 15:38:04.575216: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# array([[6.8511031e-06, 9.8952311e-01, 2.2075425e-03, 7.3517207e-08,
#         8.2597658e-03, 7.4093887e-10, 2.6542455e-06, 3.6812587e-08]],
#       dtype=float32)

# %%
y_pred = y_prob.argmax(axis=-1)
print(y_pred)
print(len(y_pred))
# Out:
# [1]
# 1

# %%
number_of_examples = len(test_generator.filenames)
number_of_generator_calls = math.ceil(number_of_examples / (1.0 * batch_size)) 
# 1.0 above is to skip integer division

y_test = []

for i in range(0,int(number_of_generator_calls)):
    y_test.extend(np.argmax(np.array(test_generator[i][1]),axis=-1))

print(y_test)
print(len(y_test))
# Out:
# [0]
# 1

# %%
df=pd.read_csv('CNN Model/soil_properties.csv')
df.set_index('soil_type', inplace=True)
df
# Out:
#               organic_matter water_capacity  \
# soil_type
# Arid Soil               2-4%            low
# Black Soil            40-50%           high
# Cinder Soil             5-7%            low
# Laterite Soil           0-5%            low
# Peat Soil             33-67%      very high
# Red Soil                4-8%            low
# Saline Soil             0-4%       moderate
# Yellow Soil             2-5%       very low
#
#                                                         minerals  pH_level  \
# soil_type
# Arid Soil                     gypsum, calcium carbonates, sodium  8.5-10.0
# Black Soil     iron, lime, calcium, potash, magnesium, aluminium   7.2-8.5
# Cinder Soil                      aluminium, iron, sodium, carbon   6.6-7.8
# Laterite Soil  nitrogen, phosphorus, potassium, lime, magnesi...   5.5-7.5
# Peat Soil                                        iron, aluminium   3.7-5.2
# Red Soil                  iron, potassium, nitrogen, phosphorous   5.6-7.1
# Saline Soil                   sodium, gypsum, magnesium, calcium     7-8.5
# Yellow Soil                    iron, sodium, potassium, nitrogen   6.6-7.3
#
#                                                          regions  \
# soil_type
# Arid Soil             haryana, western rajasthan, punjab, gujrat
# Black Soil        gujrat, maharashtra, karnataka, madhya pradesh
# Cinder Soil    bihar, southern uttaranchal, west bengal, oris...
# Laterite Soil  western ghats, eastern ghats, southern maharas...
# Peat Soil      southern uttarakhand, northern bihar, coastal ...
# Red Soil       tamil nadu, karnataka, southern maharashtra, e...
# Saline Soil    gujrat, bihar, haryana, rajasthan, maharashtra...
# Yellow Soil    odisha, chattisgarh, west bengal, maharashtra,...
#
#                                                     what_to_grow  water_val  \
# soil_type
# Arid Soil          barley, cotton, wheat, millets, maize, pulses        0.2
# Black Soil     cotton, wheat, jowar, linseed, castor, sunflow...        0.4
# Cinder Soil    beans, bok choy, chard, chives, garlic, leek, ...        0.2
# Laterite Soil  tea, coffee, rubber, cinchona, coconut, areca nut        0.2
# Peat Soil      potatoes, sugar beet, celery, onions, carrots,...        0.5
# Red Soil       cotton, wheat, rice, pulses, millets, tobacco,...        0.2
# Saline Soil    cotton, alfalfa, cereals, grain sorghum, sugar...        0.3
# Yellow Soil    Rice, wheat, sugarcane, maize/corn, groundnut,...        0.1
#
#                ph_val  organic_val
# soil_type
# Arid Soil        9.25          3.0
# Black Soil       7.85         45.0
# Cinder Soil      7.20          6.0
# Laterite Soil    6.50          2.5
# Peat Soil        4.45         50.0
# Red Soil         6.35          6.0
# Saline Soil      7.75          2.0
# Yellow Soil      6.95          3.5

# %%
def find_top_soils(prob):
    op=[]
    for i in range(no_of_classes):
        if(prob[i]>0.05):
            op.append(i)
    return op

def find_regions(soils):
    op=[]
    for i,v in enumerate(soils):
        sub=str(df.at[v,'regions'])
        subs=sub.split(", ")
        for k in subs:
            op.append(k)
    return list(set(op))

def find_whattogrow(soils):
    op=[]
    for i,v in enumerate(soils):
        sub=str(df.at[v,'what_to_grow'])
        subs=sub.split(", ")
        for k in subs:
            op.append(k)
    return list(set(op))

def find_minerals(soils):
    op=[]
    for i,v in enumerate(soils):
        sub=str(df.at[v,'minerals'])
        subs=sub.split(", ")
        for k in subs:
            op.append(k)
    return list(set(op))

def find_moisture(prob):
    op=0
    for i in range(no_of_classes):
        op+=(df.iat[i,6]*prob[i])
    return op*100

def find_ph(prob):
    op=0
    for i in range(no_of_classes):
        op+=(df.iat[i,7]*prob[i])
    return op

def find_organic(prob):
    op=0
    for i in range(no_of_classes):
        op+=(df.iat[i,8]*prob[i])
    return op

# %% [markdown]
# # FRONT END

# %%
show_grid(x,1,test_generator.samples,label_list=y_int,show_labels=True,figsize=(20,10))

# %%
for i,v in enumerate(y_prob):
    top_idx=find_top_soils(v)
    top= [class_labels[j] for j in top_idx]
    max_soil=class_labels[y_pred[i]]
    regions=find_regions(top)
    whattogrow=find_whattogrow(top)
    minerals=find_minerals(top)
    moisture=find_moisture(v)
    ph=find_ph(v)
    organic=find_organic(v)

    
    print("\n")
    print("IMAGE",i+1)
    print("\n")
    print("Maximum Soil Type Content:", max_soil)
    print("\n")
    print("Top soils:", *top, sep=", ")
    print("\n")
    print("Moisture:", round(moisture,2),"%")
    print("\n")
    print("pH:", round(ph,2))
    print("\n")
    print("Oranic Matter:", round(organic,2),"%")
    print("\n")
    print("Regions:", *regions, sep=', ')
    print("\n")
    print("What to Grow:", *whattogrow, sep=', ')
    print("\n")
    print("Minerals:", *minerals, sep=', ')
    print("_"*200)
# Out:
# IMAGE 1
#
#
# Maximum Soil Type Content: Black Soil
#
#
# Top soils:, Black Soil
#
#
# Moisture: 40.04 %
#
#
# pH: 7.82
#
#
# Oranic Matter: 44.95 %
#
#
# Regions:, madhya pradesh, gujrat, maharashtra, karnataka
#
#
# What to Grow:, jowar, sunflower and millets, linseed, cotton, wheat, castor
#
#
# Minerals:, magnesium, aluminium, iron, potash, calcium, lime
# ________________________________________________________________________________________________________________________________________________________________________________________________________
